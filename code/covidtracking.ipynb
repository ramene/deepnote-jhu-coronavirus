# %% [markdown]
# ## Save data to the project and do some exploration if desired

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %%
usin = 'https://covidtracking.com/api/us/daily.csv'
statesin = 'https://covidtracking.com/api/v1/states/current.csv'

usout = '../data/raw/covidtracking/us_historical.csv'
statesout = '../data/raw/covidtracking/states_historical.csv'

# %% [markdown]
# #### not going to merge in the numbers from the current day, but you can do so if you like

# %%
pd.read_csv('https://covidtracking.com/api/v1/us/current.csv')
# Out:
#    positive  negative  pending  hospitalizedCurrently  hospitalizedCumulative  \
# 0    801038   3362426    11194                  58542                   84657
#
#    inIcuCurrently  inIcuCumulative  onVentilatorCurrently  \
# 0           15251             2291                   5544
#
#    onVentilatorCumulative  recovered  \
# 0                     214      59697
#
#                                        hash lastModified  death  hospitalized  \
# 0  6f6c3725f25cfeffee7b646e4c7274565d95f332    4/22/2020  40097         84657
#
#      total  totalTestResults   posNeg  \
# 0  4174658           4163464  4163464
#
#                                                notes
# 0  NOTE: "total", "posNeg", "hospitalized" will b...

# %%
pd.read_csv('https://covidtracking.com/api/v1/states/current.csv').head(2)
# Out:
#   state  positive  positiveScore  negativeScore  negativeRegularScore  \
# 0    AK       329            1.0            1.0                   1.0
# 1    AL      5327            1.0            1.0                   0.0
#
#    commercialScore grade  score  negative  pending  ...  death  hospitalized  \
# 0              1.0     A    4.0     10790      NaN  ...    9.0          36.0
# 1              1.0     B    3.0     43295      NaN  ...  186.0         697.0
#
#    total  totalTestResults  posNeg  fips          dateModified  \
# 0  11119             11119   11119     2  2020-04-21T19:15:00Z
# 1  48622             48622   48622     1  2020-04-21T04:00:00Z
#
#             dateChecked                                              notes  \
# 0  2020-04-21T19:32:00Z  Please stop using the "total" field. Use "tota...
# 1  2020-04-22T03:00:00Z  Please stop using the "total" field. Use "tota...
#
#                                        hash
# 0  21e3abbf65693963556e477f74528ac4437f9ef1
# 1  f0de445f1b0d603197e43096a60fa545a9ab5860
#
# [2 rows x 29 columns]

# %% [markdown]
# #### get historical numbers

# %%
df = pd.read_csv(usin)
dfs = pd.read_csv(statesin)

# %%
df.to_csv(usout)
dfs.to_csv(statesout)

# %% [markdown]
# #### brief exploration

# %%
df.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20200421      56    799717  3355461.0   3956.0                58468.0
# 1  20200420      56    772524  3231027.0   4037.0                55509.0
# 2  20200419      56    749203  3116661.0  11324.0                55565.0
# 3  20200418      56    722182  2976352.0   9906.0                56575.0
# 4  20200417      56    694520  2862973.0  10889.0                57858.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                 84292.0         15228.0           2315.0
# 1                 82879.0         14691.0           2193.0
# 2                 80881.0         14548.0           2145.0
# 3                 78839.0         14788.0           2096.0
# 4                 77955.0         14910.0           2052.0
#
#    onVentilatorCurrently  ...  death  hospitalized    total totalTestResults  \
# 0                 5514.0  ...  39995       84292.0  4159134          4155178
# 1                 5567.0  ...  37321       82879.0  4007588          4003551
# 2                 5603.0  ...  35793       80881.0  3877188          3865864
# 3                 5729.0  ...  34139       78839.0  3708440          3698534
# 4                 6096.0  ...  32365       77955.0  3568382          3557493
#
#     posNeg  deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 0  4155178         2674.0                1413.0          124434.0
# 1  4003551         1528.0                1998.0          114366.0
# 2  3865864         1654.0                2042.0          140309.0
# 3  3698534         1774.0                 884.0          113379.0
# 4  3557493         2069.0                3250.0          125169.0
#
#    positiveIncrease  totalTestResultsIncrease
# 0           27193.0                  151627.0
# 1           23321.0                  137687.0
# 2           27021.0                  167330.0
# 3           27662.0                  141041.0
# 4           31260.0                  156429.0
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#                date     states       positive      negative       pending  \
# count  5.400000e+01  54.000000      54.000000  5.000000e+01     49.000000
# mean   2.020035e+07  48.518519  221057.462963  1.014031e+06  18919.551020
# std    5.261954e+01  16.598182  264891.447008  1.100562e+06  22631.721321
# min    2.020023e+07   1.000000       9.000000  6.000000e+00    103.000000
# 25%    2.020031e+07  51.000000    2439.500000  2.599400e+04   1691.000000
# 50%    2.020033e+07  56.000000   78159.500000  5.785140e+05  14433.000000
# 75%    2.020041e+07  56.000000  416755.750000  1.884609e+06  17303.000000
# max    2.020042e+07  56.000000  799717.000000  3.355461e+06  65709.000000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count              31.000000               32.000000       27.000000
# mean            33405.870968            41293.843750     9235.111111
# std             21467.973438            27746.699318     5244.829544
# min               112.000000             1964.000000     1299.000000
# 25%             14703.500000            15634.500000     4173.500000
# 50%             32996.000000            41710.500000     9932.000000
# 75%             55386.500000            63891.500000    14293.500000
# max             59420.000000            84292.000000    15228.000000
#
#        inIcuCumulative  onVentilatorCurrently  ...         death  \
# count        28.000000              28.000000  ...     54.000000
# mean       1033.571429            3323.964286  ...   8445.000000
# std         760.512567            2614.239136  ...  12172.962724
# min          74.000000             167.000000  ...      4.000000
# 25%         364.250000             547.500000  ...     52.000000
# 50%         906.500000            4103.500000  ...   1069.500000
# 75%        1732.000000            5937.750000  ...  14071.750000
# max        2315.000000            6168.000000  ...  39995.000000
#
#        hospitalized         total  totalTestResults        posNeg  \
# count     32.000000  5.400000e+01      5.400000e+01  5.400000e+01
# mean   41293.843750  1.177143e+06      1.159975e+06  1.159975e+06
# std    27746.699318  1.359402e+06      1.356417e+06  1.356417e+06
# min     1964.000000  9.000000e+00      9.000000e+00  9.000000e+00
# 25%    15634.500000  1.266075e+04      1.187350e+04  1.187350e+04
# 50%    41710.500000  5.366385e+05      4.808955e+05  4.808955e+05
# 75%    63891.500000  2.194733e+06      2.177682e+06  2.177682e+06
# max    84292.000000  4.159134e+06      4.155178e+06  4.155178e+06
#
#        deathIncrease  hospitalizedIncrease  negativeIncrease  \
# count      53.000000             53.000000         53.000000
# mean      754.547170           1590.415094      63310.584906
# std       859.998537           1599.320991      53644.980070
# min         1.000000              0.000000          0.000000
# 25%         8.000000              0.000000       3489.000000
# 50%       277.000000           1413.000000      73593.000000
# 75%      1496.000000           2652.000000     111243.000000
# max      2674.000000           5102.000000     195732.000000
#
#        positiveIncrease  totalTestResultsIncrease
# count         53.000000                 53.000000
# mean       15088.830189              78399.415094
# std        13037.045747              66327.965775
# min            9.000000                  9.000000
# 25%          751.000000               4240.000000
# 50%        17303.000000              93086.000000
# 75%        27662.000000             139536.000000
# max        34550.000000             229268.000000
#
# [8 rows x 22 columns]
